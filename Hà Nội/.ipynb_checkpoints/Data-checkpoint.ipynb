# %%
import pandas as pd
import glob

# %%
def formatter(year, index, dfname):
    months = []
    stryear = str(2008 + index)
    
    def dateformat(x):
        return str(x) + "/i/" + stryear
    
    for i in range(1, 13):
        month = year.iloc[:, [0, i]]
        month = month.rename(columns = {str(i) : dfname})
       
        #month = month.drop(month[month[dfname] < 0].index)
        
        month['date'] = month['date'].apply(dateformat)
        month['date'] = month['date'].str.replace('i', str(i))
                
        months.append(month)
        
    return pd.concat(months).fillna(0)

# %%
path = '.\Data\KTTV' 
all_files = glob.glob(path + "/*.csv")

# %%
all_files[1][12:-4]
# Out:
# 'BaVi - rain'

# %%
dfs = []

for filename in all_files:
    
    dfname = filename[12:-4]
    df = pd.read_csv(filename)
    
    years = []

    for i in range(12): #2008-2019
        istart = i * 32 + 1
        year = pd.DataFrame(data=df[istart:istart+31])
        year = year.rename(columns = {'Unnamed: 0': 'date'})
        
        year = formatter(year, i, dfname)
        years.append(year)
        
    years = pd.concat(years)
    years = years.set_index('date')
    dfs.append(years)
    print(dfname + " succeed")
    
bigframe = pd.concat(dfs, axis=1)
# Out:
# BaVi - ev succeed
# BaVi - rain succeed
# BaVi - temp succeed
# HD - ev succeed
# HD - rain succeed
# HD - temp succeed
# Lang - ev succeed
# Lang - rain succeed
# Lang - temp succeed
# ST - ev succeed
# ST - rain succeed
# ST - temp succeed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-94fad3cda4fa> in <module>
#      21     print(dfname + " succeed")
#      22
# ---> 23 bigframe = pd.concat(dfs, axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282     )
#     283
# --> 284     return op.get_result()
#     285
#     286
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     495
#     496             new_data = concatenate_block_managers(
# --> 497                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     498             )
#     499             if not self.copy:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2025         blocks.append(b)
#    2026
# -> 2027     return BlockManager(blocks, axes)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     137
#     138         if do_integrity_check:
# --> 139             self._verify_integrity()
#     140
#     141         self._consolidate_check()
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     332         for block in self.blocks:
#     333             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 334                 construction_error(tot_items, block.shape[1:], self.axes)
#     335         if len(self.items) != tot_items:
#     336             raise AssertionError(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in construction_error(tot_items, block_shape, axes, e)
#    1692     if block_shape[0] == 0:
#    1693         raise ValueError("Empty data passed with indices specified.")
# -> 1694     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#    1695
#    1696
#
# ValueError: Shape of passed values is (4668, 12), indices imply (4500, 12)

# %%
for df in dfs:
    print(df.shape)
# Out:
# (4464, 1)
# (4464, 1)
# (4464, 1)
# (4464, 1)
# (4260, 1)
# (4464, 1)
# (4464, 1)
# (4464, 1)
# (4464, 1)
# (4464, 1)
# (4464, 1)
# (4464, 1)

# %%
df[4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 4
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-eee2bd5ac8b1> in <module>
# ----> 1 df[4]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 4

# %%
bigframe = bigframe.drop(bigframe[bigframe['rainfall'] < 0].index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e44ed10c79d0> in <module>
# ----> 1 bigframe = bigframe.drop(bigframe[bigframe['rainfall'] < 0].index)
#
# NameError: name 'bigframe' is not defined

# %%
bigframe.describe()
# Out:
#            avgtemp  evaporation            H             Q     rainfall
# count  4383.000000  4383.000000  4383.000000   4383.000000  4383.000000
# mean     24.161123     1.870272   510.341091   3105.640657     4.717545
# std       5.300147     0.977685   197.740173   2148.302734    14.913955
# min       6.700000     0.100000   118.000000    493.000000     0.000000
# 25%      20.400000     1.200000   365.000000   1550.000000     0.000000
# 50%      25.500000     1.800000   477.000000   2550.000000     0.000000
# 75%      28.300000     2.400000   626.500000   3945.000000     1.600000
# max      35.700000     8.300000  1216.000000  14800.000000   267.300000

# %%
bigframe.to_csv(path + '\SonTay.csv')

# %%
bigframe['Q'].plot(figsize =(10,8))

# %%
bigframe['H'].plot(figsize=(10,8))

# %%
# Matplotlib forms basis for visualization in Python
import matplotlib.pyplot as plt

# We will use the Seaborn library
import seaborn as sns
sns.set()

# %%
corr_matrix = bigframe.corr()
sns.heatmap(corr_matrix, annot=True)
